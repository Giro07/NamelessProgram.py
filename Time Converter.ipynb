# %%
def time_converter(num, entrada, saida):
    if entrada == "s":
        if saida == "min":
            num = num/60
        elif saida == "h":
            num = num/(3600)
        elif saida == "dia":
            num = num/(3600*24)
        elif saida == "semana":
            num = num/(3600*24*7)
        elif saida == "mes":
            num = num/(3600*24*30)
        elif saida == "ano":
            num = num/(3600*24*365)
            
    elif entrada == "min":
        if saida == "s":
            num = num*60
        elif saida == "h":
            num = num/(60)
        elif saida == "dia":
            num = num/(60*24)
        elif saida == "semana":
            num = num/(60*24*7)
        elif saida == "mes":
            num = num/(60*24*30)
        elif saida == "ano":
            num = num/(60*24*365)
            
    elif entrada == "h":
        if saida == "s":
            num = num*3600
        elif saida == "min":
            num = num*60
        elif saida == "dia":
            num = num/24
        elif saida == "semana":
            num = num/(24*7)
        elif saida == "mes":
            num = num/(24*30)
        elif saida == "ano":
            num = num/(24*365)
            
    elif entrada == "dia":
        if saida == "s":
            num = num*(3600*24)
        elif saida == "min":
            num = num*(60*24)
        elif saida == "h":
            num = num*24
        elif saida == "semana":
            num = num/7
        elif saida == "mes":
            num = num/30
        elif saida == "ano":
            num = num/365
            
    elif entrada == "semana":
        if saida == "s":
            num = num*(3600*24*7)
        elif saida == "min":
            num = num*(60*24*7)
        elif saida == "h":
            num = num*24*7
        elif saida == "dia":
            num = num*7
        elif saida == "mes":
            num = num/4
        elif saida == "ano":
            num = num/52
        
    elif entrada == "mes":
        if saida == "s":
            num = num*(3600*24*30)
        elif saida == "min":
            num = num*(60*24*30)
        elif saida == "h":
            num = num*24*30
        elif saida == "dia":
            num = num*30
        elif saida == "semana":
            num = num*4
        elif saida == "ano":
            num = num/12
        
    elif entrada == "ano":
        if saida == "s":
            num = num*(3600*24*30*12)
        elif saida == "min":
            num = num*(60*24*30*12)
        elif saida == "h":
            num = num*24*30*12
        elif saida == "dia":
            num = num*365
        elif saida == "semana":
            num = num*52
        elif saida == "mes":
            num = num*12
            
    return (num,saida)

# %%
time_converter(1,"mes","s")
# Out:
# (2592000, 's')
